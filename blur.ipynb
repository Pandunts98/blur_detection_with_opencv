# %%
from blur_detection import get_blurs
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
path = os.getcwd() + '\\bad_examples'
path
# Out:
# 'C:\\Users\\user\\Downloads\\task1\\bad_examples'

# %%
percent_blurred, blur_objects = get_blurs(path, threshold=300)

# %%
percent_blurred                   # percentage of blurred objects for each image
# Out:
# {'new_large_1095.xml': 0.0,
#  'new_large_1096.xml': 9.090909090909092,
#  'new_large_1102.xml': 14.285714285714285,
#  'new_large_1104.xml': 12.5,
#  'new_large_1107.xml': 0.0,
#  'new_large_3175.xml': 51.85185185185185,
#  'new_large_3176.xml': 40.909090909090914,
#  'new_large_3177.xml': 53.84615384615385,
#  'new_large_3178.xml': 52.38095238095239,
#  'new_large_3180.xml': 44.44444444444444,
#  'new_large_3181.xml': 46.666666666666664,
#  'total_percent': 29.634162134162136}

# %%
plt.figure(figsize=(20,10))
plt.hist(blur_objects, bins=200)
plt.title('how blurry a given image ')
plt.xlabel('amount of blur')
plt.ylabel('count')
plt.show()
